# %% [markdown]
# Importing **Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Importing the Dataset:**

# %%
dataset =pd.read_csv("/content/weatherAUS[1].csv")

# %%
dataset.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
dataset.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
dataset.shape
# Out:
# (145460, 23)

# %%
dataset.dtypes
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object
# dtype: object

# %%
dataset['Date']=pd.to_datetime(dataset['Date'])
dataset['year']=dataset['Date'].dt.year
dataset['month']=dataset['Date'].dt.month
dataset['day']=dataset['Date'].dt.day

# %%
dataset.drop(['Date'],axis=1,inplace=True)

# %%
dataset['RainToday'].replace({'No':0,'Yes':1},inplace=True)
dataset['RainTomorrow'].replace({'No':0,'Yes':1},inplace=True)

# %%
dataset.tail()
# Out:
#        Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 145455    Uluru      2.8     23.4       0.0          NaN       NaN
# 145456    Uluru      3.6     25.3       0.0          NaN       NaN
# 145457    Uluru      5.4     26.9       0.0          NaN       NaN
# 145458    Uluru      7.8     27.0       0.0          NaN       NaN
# 145459    Uluru     14.9      NaN       0.0          NaN       NaN
#
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Pressure3pm  \
# 145455           E           31.0         SE        ENE  ...       1020.3
# 145456         NNW           22.0         SE          N  ...       1019.1
# 145457           N           37.0         SE        WNW  ...       1016.8
# 145458          SE           28.0        SSE          N  ...       1016.5
# 145459         NaN            NaN        ESE        ESE  ...       1017.9
#
#         Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  year  \
# ...

# %% [markdown]
# **Checking and dealing with imbalance of data:**

# %%
print('Yes RainTomorrow counts:',dataset[(dataset['RainTomorrow']==1)].RainTomorrow.count())
print('No RainTomorrow counts:',dataset[(dataset['RainTomorrow']==0)].RainTomorrow.count())
# Out:
# Yes RainTomorrow counts: 31877
# No RainTomorrow counts: 110316

# %%
from sklearn.utils import resample
no_rt=dataset[dataset['RainTomorrow']==0]
yes_rt=dataset[dataset['RainTomorrow']==1]
oversampled_yes_rt=resample(yes_rt,replace=True,n_samples=len(no_rt),random_state=137)

# %%
fil_dataset=pd.concat([no_rt,oversampled_yes_rt])

# %%
print('Yes RainTomorrow counts:',fil_dataset[(fil_dataset['RainTomorrow']==1)].RainTomorrow.count())
print('No RainTomorrow counts:',fil_dataset[(fil_dataset['RainTomorrow']==0)].RainTomorrow.count())
# Out:
# Yes RainTomorrow counts: 110316
# No RainTomorrow counts: 110316

# %%
print(fil_dataset.select_dtypes(include=['object']).columns)
# Out:
# Index(['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm'], dtype='object')

# %%
print(fil_dataset.isnull().sum())
# Out:
# Location              0
# MinTemp            1091
# MaxTemp             440
# Rainfall           3035
# Evaporation       95579
# Sunshine         104972
# WindGustDir       15451
# WindGustSpeed     15333
# WindDir9am        14817
# WindDir3pm         6282
# WindSpeed9am       2203
# WindSpeed3pm       4246
# Humidity9am        3115
# Humidity3pm        5874
# Pressure9am       21699
# Pressure3pm       21669
# Cloud9am          81289
# Cloud3pm          85473
# Temp9am            1676
# Temp3pm            4473
# RainToday          3035
# RainTomorrow          0
# year                  0
# month                 0
# day                   0
# dtype: int64

# %% [markdown]
# **Dealing with null values of Categorical Variables:**

# %%
list=['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm']
for item in list:
  fil_dataset[item]=fil_dataset[item].fillna(fil_dataset[item].mode()[0])

# %%
print(fil_dataset.isnull().sum())
# Out:
# Location              0
# MinTemp            1091
# MaxTemp             440
# Rainfall           3035
# Evaporation       95579
# Sunshine         104972
# WindGustDir           0
# WindGustSpeed     15333
# WindDir9am            0
# WindDir3pm            0
# WindSpeed9am       2203
# WindSpeed3pm       4246
# Humidity9am        3115
# Humidity3pm        5874
# Pressure9am       21699
# Pressure3pm       21669
# Cloud9am          81289
# Cloud3pm          85473
# Temp9am            1676
# Temp3pm            4473
# RainToday          3035
# RainTomorrow          0
# year                  0
# month                 0
# day                   0
# dtype: int64

# %% [markdown]
# **Dealing with null values of Numerical variables:**

# %%
fil_dataset[fil_dataset.columns[fil_dataset.isna().any()]].columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am',
#        'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm',
#        'Temp9am', 'Temp3pm', 'RainToday'],
#       dtype='object')

# %%
null_list=['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
       'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am',
       'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm',
       'Temp9am', 'Temp3pm', 'RainToday']
for k in null_list:
  fil_dataset[k]=fil_dataset[k].fillna(fil_dataset[k].mean())

# %%
print(fil_dataset.isnull().sum())
# Out:
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# year             0
# month            0
# day              0
# dtype: int64

# %% [markdown]
# **Encoding Categorical variables :**

# %%
from sklearn.preprocessing import LabelEncoder
encoders={}
for j in list:
  encoders[j]=LabelEncoder()
  fil_dataset[j]=encoders[j].fit_transform(fil_dataset[j])

# %%
print(fil_dataset.dtypes)
# Out:
# Location           int64
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir        int64
# WindGustSpeed    float64
# WindDir9am         int64
# WindDir3pm         int64
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday        float64
# RainTomorrow     float64
# year               int64
# month              int64
# day                int64
# dtype: object

# %%
fil_dataset.shape
# Out:
# (220632, 25)

# %%
fil_dataset.head()
# Out:
#    Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0         2     13.4     22.9       0.6     5.129684  6.494697           13
# 1         2      7.4     25.1       0.0     5.129684  6.494697           14
# 2         2     12.9     25.7       0.0     5.129684  6.494697           15
# 3         2      9.2     28.0       0.0     5.129684  6.494697            4
# 4         2     17.5     32.3       1.0     5.129684  6.494697           13
#
#    WindGustSpeed  WindDir9am  WindDir3pm  ...  Pressure3pm  Cloud9am  \
# 0           44.0          13          14  ...       1007.1  8.000000
# 1           44.0           6          15  ...       1007.8  5.047064
# 2           46.0          13          15  ...       1008.7  5.047064
# 3           24.0           9           0  ...       1012.8  5.047064
# 4           41.0           1           7  ...       1006.0  7.000000
#
#    Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  year  month  day
# ...

# %%
x=fil_dataset.iloc[:,fil_dataset.columns!='RainTomorrow']
y=fil_dataset['RainTomorrow']

# %% [markdown]
# **Scaling the dataset:**

# %%
from sklearn.preprocessing import MinMaxScaler
sc=MinMaxScaler()
x=sc.fit_transform(x)

# %% [markdown]
# **Selecting K most relevant features:**

# %%
from sklearn.feature_selection import chi2,SelectKBest
k_best=SelectKBest(score_func=chi2,k=15)
k_best.fit(x,y)
# Out:
# SelectKBest(k=15, score_func=<function chi2 at 0x7d4020ba88b0>)

# %%
x_new=k_best.transform(x)

# %% [markdown]
# **Splitting the dataset:**

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_new,y,test_size=0.3,stratify=y,random_state=137,shuffle=True)

# %% [markdown]
# **Building and training the model:**

# %%
import xgboost as xgb
xgb_param={'n_estimators':500,
           'max_depth':16}
model=xgb.XGBClassifier(**xgb_param)
model.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=16, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=500, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# **Evaluating the model:**

# %%
from sklearn.metrics import classification_report
y_pred=model.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.90      0.93     33095
#          1.0       0.91      0.97      0.94     33095
#
#     accuracy                           0.94     66190
#    macro avg       0.94      0.94      0.94     66190
# weighted avg       0.94      0.94      0.94     66190

# %%
from sklearn.metrics import confusion_matrix
cf=confusion_matrix(y_test,y_pred)
sns.heatmap(cf,annot=True)
plt.xlabel('Actual Value')
plt.ylabel('Predicted Value')
plt.show()

# %%
a=3e+04
b=3.2e+04
c=9.9e+02
d=3.2e+03

# %%
acc=(a+b)/(a+b+c+d)
print('Accuracy:',acc*100,'%')
# Out:
# Accuracy: 93.66973863121318 %

# %% [markdown]
# **This was a project concerned with Predicting rainfall based on the rainfall dataset of Australia over the past 10 years using Machine Learning.**
